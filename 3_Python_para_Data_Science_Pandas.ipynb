# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosMza/Python_para_Data_Science_Pandas/blob/main/3_Python_para_Data_Science_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=green> PYTHON PARA DATA SCIENCE - PANDAS
# ---

# %% [markdown]
# # <font color=green> 1. INTRODUCCIÓN A PYTHON
# ---

# %% [markdown]
# # 1.1 Introducción

# %% [markdown]
# > Python es un lenguaje de programación de alto nivel con soporte a múltiples paradigmas de programación. Es un proyecto *open source* y desde su aparición en 1991, viene convirtiéndose en uno de los lenguajes de programación interpretados más populares.
# >
# > En los últimos años Python ha desarrollado una comunidad activa de procesamiento científico y análisis de datos y viene destacándose como uno de los lenguajes más relevantes cuando el asunto es ciencia de datos y machine learning, tanto en el entorno académico como también en el entorno laboral.

# %% [markdown]
# # 1.2 Instalación y entorno de trabajo

# %% [markdown]
# ### Instalación Local
#
# ### https://www.python.org/downloads/
# ### o
# ### https://www.anaconda.com/distribution/

# %% [markdown]
# ### Google Colaboratory
#
# ### https://colab.research.google.com

# %% [markdown]
# ### Verificando versión

# %% [markdown]
# # 1.3 Trabajando con datos

# %%
import pandas as pd
# aplicamos un -método set.option()- para poder ver x cantidad de filas o columnas del dataset
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

# %%
# al tener un archivo csv, con la extensión -read_csv- vamos a pasar el archivo a un formato donde se pueda leer claramente
dataset = pd.read_csv('db.csv',sep = ';')

# %%
dataset
# Out:
#                     Nombre                  Motor   Año  Kilometraje  Cero_km  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003      44410.0    False
# 1                   Passat           Motor Diesel  1991       5712.0    False
# 2                 Crossfox        Motor Diesel V8  1990      37123.0    False
# 3                      DS5        Motor 2.4 Turbo  2019          NaN     True
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006      25757.0    False
# ..                     ...                    ...   ...          ...      ...
# 253           Phantom 2013               Motor V8  2014      27505.0    False
# 254  Cadillac Ciel concept               Motor V8  1991      29981.0    False
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# 256       Aston Martin DB5           Motor Diesel  1996       7685.0    False
# 257                  Macan        Motor Diesel V6  1992      50188.0    False
#
# ...

# %%
dataset.dtypes
# Out:
# Nombre          object
# Motor           object
# Año              int64
# Kilometraje    float64
# Cero_km           bool
# Accesorios      object
# Valor          float64
# dtype: object

# %%
# Vamos a traer solo dos columnas del archivo para analizar con el método -describe()-
dataset[['Kilometraje','Valor']].describe()
# El método describe() genera un conjunto de estadísticas descriptivas de las columnas seleccionadas de un DataFrame.
# Out:
#          Kilometraje          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
# con el método -info()- nos trae la información del dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       258 non-null    object
#  1   Motor        258 non-null    object
#  2   Año          258 non-null    int64
#  3   Kilometraje  197 non-null    float64
#  4   Cero_km      258 non-null    bool
#  5   Accesorios   258 non-null    object
#  6   Valor        258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# # <font color=green> 2. TRABAJANDO CON TUPLAS
# ---

# %% [markdown]
# # 2.1 Creando tuplas
#
# Tuplas son secuencias **inmutables** que son utilizadas para guardar colecciones de objetos, geralmente heterogéneos. Pueden ser construídas de varias formas:
# ```
# - Utilizando un par de paréntesis: ( )
# - Utilizando una coma a la derecha: x,
# - Utilizando un par de paréntesis con objetos separados por comas: ( x, y, z )
# - Utilizando: tuple() o tuple(iterador)
# ```

# %%
# Tupla vacía
()
# Out:
# ()

# %%
# Tupla con elementos separados por ','
1, 2, 3

'''
No es necesario usar paréntesis para definir una tupla,
basta con definir los elementos y separarlos con comas.
'''
# Out:
# (1, 2, 3)

# %%
# creamos una tupla con dos parámetros
nombre = 'Passat'
valor = 153000
(nombre,valor)

'''
Podemos crear una tupla usando paréntesis, con sus elementos separados por comas.
'''
# Out:
# ('Passat', 153000)

# %%
# en este caso vamos a convertir una lista en una tupla
nombre_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nombre_carros
'''
El tipo tuple permite crear tuplas, utilizando algún tipo de iterador
como argumento. En este caso, fue utilizada una lista de Python.
'''
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
# vemos que tipo de datos es 'nombre_carros'
type(nombre_carros)
# Out:
# tuple

# %% [markdown]
# # 2.2 Selecciones en tuplas

# %%
# vamos a ver como accesar a los elementos dentro de la tupla
nombre_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nombre_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
# accedemos al primer elemento
nombre_carros[0]
# Out:
# 'Jetta Variant'

# %%
# accedemos al segundo elemento
nombre_carros[1]
# Out:
# 'Passat'

# %%
# accedemos al último elemento
nombre_carros[-1]
# Out:
# 'DS5'

# %%
# partimos la tupla y vemos elementos intermedios
nombre_carros[1:3]
# Out:
# ('Passat', 'Crossfox')

# %%
nombres_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))

# %%
# accedemos el último valor de la tupla
nombres_carros[-1]
# Out:
# ('Fusca', 'Gol', 'C4')

# %%
# accedemos el último valor de la tupla, vemos que es otra tupla y
# luego al segundo elemento dentro de la última tupla
nombres_carros[-1][1]
# Out:
# 'Gol'

# %%
# Ejemplo:
carros = (
    (
        'Jetta Variant',
        'Motor 4.0 Turbo',
        2003,
        False,
        ('Llantas de aleación', 'Cerraduras eléctricas', 'Piloto automático')
    ),
    (
        'Passat',
        'Motor Diesel',
        1991,
        True,
        ('Central multimedia', 'Techo panoramico', 'Frenos ABS')
    )
)

# %%
# En este caso tenemos dos elementos que son tuplas, accedemos al cuarto elemento
# que se encuentra dentro de la primera tupla
carros [0][3]
# Out:
# False

# %%
# En este caso accedemos al último elemento que es una tupla, luego volvemos a buscar el
# último valor que es otra tupla y finalmente accedemos al valor de la última posición
carros [-1][-1][-1]
# Out:
# 'Frenos ABS'

# %%
# En este caso accedemos a los dos primeros elementos que se encuentran en la tupla
# ubicada en la última posición del primer elemento de carros
carros[0][-1][:2]
# Out:
# ('Llantas de aleación', 'Cerraduras eléctricas')

# %% [markdown]
# # 2.3 Iterando en tuplas

# %%
nombres_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
# vamos a iterar a través de un bucle 'for'
for item in nombres_carros:
  print(item)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DS5

# %% [markdown]
# ### Desempacando tuplas

# %%
nombres_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nombres_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
# Creamos 4 variables y le asignamos los elementos de la tupla 'nombres_carros'
carro_1, carro_2, carro_3, carro_4 = nombres_carros

# Lo que hacemos en este caso es lo que se llama desempacar una tupla

# %%
carro_1
# Out:
# 'Jetta Variant'

# %%
carro_2
# Out:
# 'Passat'

# %%
carro_3
# Out:
# 'Crossfox'

# %%
carro_4
# Out:
# 'DS5'

# %%
# En este caso solo quiero guardar algunas variables no todas, lo vamos a realizar con un 'undercorse'(_)
_, A, _, B = nombres_carros

# vemos que solo guarda los elementos en las variables A y B con los elementos de posición 1 y 4

# %%
A
# Out:
# 'Passat'

# %%
B
# Out:
# 'DS5'

# %%
# Otra forma de hacerlo es '*_', guardamos el valor de la segunda posición en la
# variable C y el resto son ignorados
_, C, *_ = nombres_carros

# %%
C
# Out:
# 'Passat'

# %% [markdown]
# ## *zip()*
#
# https://docs.python.org/3.6/library/functions.html#zip

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
# zip() es un iterador, para ver los valores lo convertimos en una lista
# los ordena los elementos de carros con los elementos de valores
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
# vamos a realizar un bucle 'for' para recorrer los elementos
for item in zip(carros, valores):
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)

# %%
# ahora vamos a desempacar las tuplas
for carro, valor in zip(carros, valores):
  print(carro, valor)

# podemos ver obtenemos cada uno de los valores de carro y valor por separados
# Out:
# Jetta Variant 88078.64
# Passat 106161.94
# Crossfox 72832.16
# DS5 124549.07

# %%
# como hemos desempacados los elementos y los puedo utilizar individualmente,
# buscamos los vehículos que su valor sea mayor a 100.000
for carro, valor in zip(carros, valores):
  if(valor > 100000):
    print(carro)
# Out:
# Passat
# DS5

# %%
# Ejemplo:
nombres = ['Passat', 'Crossfox', 'DS5', 'C4', 'Jetta']
kms = [15000, 12000, 32000, 8000, 50000]

# %%
# buscamos que autos tienen menos de 20.000 km
for nombre, km in zip(nombres, kms):
  if(km < 20000):
    print(nombre)
    '''
Observa que, en la construcción del bucle for (primera línea del código),
usamos el desempaquetado de tuplas y la función zip().
'''
# Out:
# Passat
# Crossfox
# C4

# %%
# Ejemplo
carros = (
    (
        'Jetta Variant',
        'Motor 4.0 Turbo',
        2003,
        False,
        ('Llantas de aleación', 'Cerraduras eléctricas', 'Piloto automático')
    ),
    (
        'Passat',
        'Motor Diesel',
        1991,
        True,
        ('Central multimedia', 'Techo panoramico', 'Frenos ABS')
    )
)

# Quiero obtener como resultado:
'''
Llantas de aleación
Cerraduras eléctricas
Piloto automático
Central multimedia
Techo panorámico
Frenos ABS
'''

# %%
# En este caso recorre los valores de carro y va a imprimir los elementos de la
# última posición de cada tupla
for tupla in carros:
  print (tupla[-1])
# Out:
# ('Llantas de aleación', 'Cerraduras eléctricas', 'Piloto automático')
# ('Central multimedia', 'Techo panoramico', 'Frenos ABS')

# %%
# En este caso itera carros y las tuplas que tiene como elementos en carros, e imprime todos los elementos
for tupla in carros:
  for item in tupla:
    print(item)
# Out:
# Jetta Variant
# Motor 4.0 Turbo
# 2003
# False
# ('Llantas de aleación', 'Cerraduras eléctricas', 'Piloto automático')
# Passat
# Motor Diesel
# 1991
# True
# ('Central multimedia', 'Techo panoramico', 'Frenos ABS')

# %%
# En este caso itera carros, luego itera los últimos elementos de la tupla que es otra tupla
# e imprime esos elementos
for tupla in carros:
  for item in tupla[-1]:
    print(item)
# Observa que, en el segundo bucle for, usamos las listas de accesorios como iterador.
# Out:
# Llantas de aleación
# Cerraduras eléctricas
# Piloto automático
# Central multimedia
# Techo panoramico
# Frenos ABS

# %%
# En este caso imprime las tuplas que tenemos como elementos dentro de carros
for tupla in carros:
  print(tupla)
# Out:
# ('Jetta Variant', 'Motor 4.0 Turbo', 2003, False, ('Llantas de aleación', 'Cerraduras eléctricas', 'Piloto automático'))
# ('Passat', 'Motor Diesel', 1991, True, ('Central multimedia', 'Techo panoramico', 'Frenos ABS'))

# %% [markdown]
# # <font color=green> 3. TRABAJANDO CON DICCIONARIOS
# ---

# %% [markdown]
# # 3.1 Creando diccionarios
#
# Listas son colecciones secuenciales, es decir, los elementos de estas secuencias están ordenados y utilizan índices (números enteros) para acceder a los valores.
#
# Los diccionarios son colecciones ligeramente diferentes. Son estructuras de datos que representan un tipo de mapeo. Los mapeos son colecciones de asociaciones entre pares de valores donde el primer elemento del par se conoce como llave (*key*) y el segundo como valor (*value*).
#
# ```
# diccionario = {key_1: value_1, key_2: value_2, ..., key_n: value_n}
# ```
#
# https://docs.python.org/3.6/library/stdtypes.html#typesmapping

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
valores = [88078.64, 106161.94, 72832.16]
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
# Método -index() para saber la posición del índice
carros.index('Passat')
# Out:
# 1

# %%
# Para obtener el valor del vehículo
valores[carros.index('Passat')]

# %%
# Creamos un diccionario, forma de crearlo "datos = {llave:valor, llave:valor}"
datos = {'Jetta Variant':88078.64, 'Passat':106161.94, 'Crossfox':72832.16}
datos
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
# vemos el tipo de estructura de nuestros datos
type(datos)
# Out:
# dict

# %% [markdown]
# ### Creando diccionarios con *zip()*

# %%
# Creamos una lista y con el iterador zip() y obtenemos una lista de tuplas
list(zip(carros,valores))

# %%
# Creamos un diccionarios utilizando el método -dict()- y el iterador -zip()-
datos = dict(zip(carros, valores))
datos
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
# Ejemplo: como crear una lista
nombres = ['Passat', 'Crossfox', 'DS5', 'C4', 'Jetta']
kms = [15000, 12000, 32000, 8000, 50000]

# %%
#  Con la función zip(), conseguimos crear diccionarios de forma simple y con poco código.
dict(zip(nombres,kms))
# Out:
# {'Passat': 15000, 'Crossfox': 12000, 'DS5': 32000, 'C4': 8000, 'Jetta': 50000}

# %% [markdown]
# # 3.2 Operaciones con diccionarios

# %%
datos = {'Jetta Variant':88078.64, 'Passat':106161.94, 'Crossfox':72832.16}
datos
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %% [markdown]
# ## *dict[ key ]*
#
# Devuelve el valor correspondiente a la llave (*key*) en el diccionario.

# %%
datos['Passat']
# Out:
# 106161.94

# %% [markdown]
# ## *key in dict*
#
# Devuelve **True** si la llave (*key*) es encontrada en el diccionario.

# %%
# buscamos una llave dentro del diccionario y obtenemos si es verdadero o falso
'Passat' in datos
# Out:
# True

# %%
'Gol' in datos
# Out:
# False

# %%
'Gol' not in datos
# Out:
# True

# %% [markdown]
# ## *len(dict)*
#
# Devuelve el número de itens del diccionario.

# %%
len(datos)
# Out:
# 3

# %% [markdown]
# ## *dict[ key ] = value*
#
# Incluye un item al diccionario.

# %%
# Forma de agregar elemento al diccionario
datos['Gol']=12456.78
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Passat': 106161.94,
#  'Crossfox': 72832.16,
#  'Gol': 12456.78}

# %% [markdown]
# ## *del dict[ key ]*
#
# Borra el item de llave (*key*) del diccionario.

# %%
# Forma de eliminar un elemento en el diccionario con el método -del-
del datos['Passat']

# %%
datos
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'Gol': 12456.78}

# %%
# Ejemplo de lo que hemos visto:
datos_1 = {
    'Passat': {
        'año': 2012,
        'km': 50000,
        'valor': 75000,
        'accesorios': ['Airbag', 'ABS']
    },
    'Crossfox': {
        'año': 2015,
        'km': 35000,
        'valor': 25000
    }
}
# Consigna
'''
Queremos lo siguiente:
1) Testar si la llave accesorios existe en el diccionario
de las informaciones del vehículo Crossfox (Respuesta esperada: False)
2) Testar si la llave accesorios existe en el diccionario de las informaciones
 del vehículo Passat (Respuesta esperada: True)
3) Obtener el valor del vehículo Crossfox (Respuesta esperada: 25000)
4) Acceder el último accesorio del vehículo Passat (Respuesta esperada: 'ABS')
'''
# Out:
# "\nQueremos lo siguiente: \n1) Testar si la llave accesorios existe en el diccionario \nde las informaciones del vehículo Crossfox (Respuesta esperada: False) \n2) Testar si la llave accesorios existe en el diccionario de las informaciones\n del vehículo Passat (Respuesta esperada: True) \n3) Obtener el valor del vehículo Crossfox (Respuesta esperada: 25000) \n4) Acceder el último accesorio del vehículo Passat (Respuesta esperada: 'ABS')\n"

# %%
# 1) Consigna:
# preguta si existe accesorios dentro del diccionario 'Crossfox'
# que se encuentra en el diccionario datos
'accesorios' in datos_1['Crossfox']
# Out:
# False

# %%
# 2) Consigna:
'accesorios' in datos_1['Passat']
# Out:
# True

# %%
# 3) Consigna:
# buscamos el elemento valor del diccionario 'Crossfox' que se encuentra
# en el diccionario 'datos'
datos_1['Crossfox']['valor']
# Out:
# 25000

# %%
# 4) Consigna:
# buscamos el último elemento de la lista accesorios, la cual es elemento
# del diccionario 'Passat', dentro del diccionario 'datos'
datos_1['Passat']['accesorios'][-1]
# Out:
# 'ABS'

# %%
'''
Observa que es muy simple acceder a las informaciones de un diccionario
dentro de otro diccionario. Primero, necesitamos acceder a la llave que tiene
como valor un diccionario y luego simplemente acceder a la llave que queremos.
'''

# %% [markdown]
# # 3.3 Métodos de diccionarios

# %% [markdown]
# ## *dict.update()*
#
# Actualiza el diccionario.

# %%
datos
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'Gol': 12456.78}

# %%
# Otra forma de agregar un elemento al diccionario con el método -update()-
# lo que hace este método también sirve para modificar el elemento
datos.update({'Passat':106161.94})
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'Gol': 12456.78,
#  'Passat': 106161.94}

# %%
# Como vemos aquí, no solo agrega el elemento 'Cruze' si no que también modifica
# el valor de 'Passat'
datos.update({'Passat': 106161.50, 'Cruze':150000})
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'Gol': 12456.78,
#  'Passat': 106161.5,
#  'Cruze': 150000}

# %%
# Ejemplo: Aplicando update()
datos_2 = {'Jetta': 88000, 'Crossfox': 72000, 'DS5': 124000}

# %%
# Agraga y actualiza los elementos
datos_2.update({'Passat':85000, 'Gol':150000})
datos_2
# Out:
# {'Jetta': 88000,
#  'Crossfox': 72000,
#  'DS5': 124000,
#  'Passat': 85000,
#  'Gol': 150000}

# %%
# Modifica y actualiza los elementos
datos_2.update({'Passat':95000, 'Gol':160000})
datos_2
# Out:
# {'Jetta': 88000,
#  'Crossfox': 72000,
#  'DS5': 124000,
#  'Passat': 95000,
#  'Gol': 160000}

# %% [markdown]
# ## *dict.copy()*
#
# Crea una copia del diccionario.

# %%
# Utilizamos una copia del diccionario con la función -copy()- si que las modificaciones
# alteren al diccionario original 'datos'
datosCopy = datos.copy()

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'Gol': 12456.78,
#  'Passat': 106161.5,
#  'Cruze': 150000}

# %%
# Eliminamos el elemento 'Gol' del diccionario datosCopy con la fc 'del'
del datosCopy['Gol']
datosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'Passat': 106161.5,
#  'Cruze': 150000}

# %%
# Observamos que en el diccionario original no se ha eliminado el elemento
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'Gol': 12456.78,
#  'Passat': 106161.5,
#  'Cruze': 150000}

# %% [markdown]
# ## *dict.pop(key[, default ])*
#
# Si la llave se encuentra en el diccionario, el elemento se elimina y se devuelve su valor. De lo contrario, se devuelve el valor especificado como *default*. Si no se proporciona el valor *default* y la llave no se encuentra en el diccionario, se generará un error.

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'Passat': 106161.5,
#  'Cruze': 150000}

# %%
# Eliminamos el elemento 'Passat' con la función -pop()-
datosCopy.pop('Passat')
# Out:
# 106161.5

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16, 'Cruze': 150000}

# %%
# Error que nos marca si queremos eliminar algún elemento que no está en la lista
datosCopy.pop('Passat')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-b1e36473b67d> in <cell line: 2>()
#       1 # Error que nos marca si queremos eliminar algún elemento que no esta en la lista
# ----> 2 datosCopy.pop('Passat')
#
# KeyError: 'Passat'

# %%
# Para que no salga el mensaje de error, le colocamos otro parámetro para que se vea mejor
datosCopy.pop('Passat', 'Llave no fue encontrada')
# Out:
# 'Llave no fue encontrada'

# %%
# Vemos que cuando el elemento si existe dentro del diccionario, cada vez que
# la llave sea encontrada, nos devuelve el valor de la llave que va a eliminar
# sin contemplar la frase
datosCopy.pop('Cruze', 'Llave no fue encontrada')
# Out:
# 150000

# %%
datosCopy
# Out:
# {'Jetta Variant': 88078.64, 'Crossfox': 72832.16}

# %%
'''
IMPORTANTE

El método pop() de un diccionario no funciona como en una lista.
En necesario proporcionar al menos un argumento para el método (llave).
Si la llave se encuentra en el diccionario, el elemento se elimina y su valor es devuelto.
'''

# %% [markdown]
# ## *dict.clear()*
#
# Borra todos los itens del diccionario.

# %%
# Eliminamos todos los elementos
datosCopy.clear()

# %%
# Vemos que nos queda el diccionario vacío
datosCopy
# Out:
# {}

# %%
'''
El método clear() elimina todos los elementos de un diccionario (llaves y valores)
y devuelve un diccionario vacío ({}).
'''

# %% [markdown]
# # 3.4 Iterando en diccionarios

# %% [markdown]
# ## *dict.keys()*
#
# Devuelve una lista con las llaves (*keys*) del diccionario.

# %%
datos = {'Jetta Variant': 88078.64,
 'Crossfox': 72832.16,
 'Gol': 12456.78,
 'Passat': 106161.5,
 'Cruze': 150000}
datos
# Out:
# {'Jetta Variant': 88078.64,
#  'Crossfox': 72832.16,
#  'Gol': 12456.78,
#  'Passat': 106161.5,
#  'Cruze': 150000}

# %%
# Utilizamos el método -key()- para obtener una lista con las llaves
datos.keys()
# Out:
# dict_keys(['Jetta Variant', 'Crossfox', 'Gol', 'Passat', 'Cruze'])

# %%
# Iteramos con un bucle for para obtener como elementos a todas las llaves del diccionario
for key in datos.keys():
  print(key)
# Out:
# Jetta Variant
# Crossfox
# Gol
# Passat
# Cruze

# %% [markdown]
# ## *dict.values()*
#
# Devuelve una lista con todos los valores (*values*) del diccionario.

# %%
# Utilizamos el método -value()- para obtener una lista con los valores
datos.values()
# Out:
# dict_values([88078.64, 72832.16, 12456.78, 106161.5, 150000])

# %% [markdown]
# ## *dict.items()*
#
# Devuelve una lista con una tupla para cada par llave-valor (*key-value*) del diccionario.

# %%
# Utilizamos el método -items()- para tener una lista de tuplas con los elemetos del diccionario
datos.items()
# Out:
# dict_items([('Jetta Variant', 88078.64), ('Crossfox', 72832.16), ('Gol', 12456.78), ('Passat', 106161.5), ('Cruze', 150000)])

# %%
# iteramos los elementos con un bucle for, para tener cada tuple por separado
for item in datos.items():
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Crossfox', 72832.16)
# ('Gol', 12456.78)
# ('Passat', 106161.5)
# ('Cruze', 150000)

# %%
# Vamos a desempacar cada tupla, separamos y mostramos cada elemento
for key, value in datos.items():
  print(key, '->', value)
# Out:
# Jetta Variant -> 88078.64
# Crossfox -> 72832.16
# Gol -> 12456.78
# Passat -> 106161.5
# Cruze -> 150000

# %%
# Para esto desempacamos los elementos de un diccionario, para poder realizar
# cálculos y aplicar condiciones en los elementos
# buscamos cuales vehículos tiene un valor mayor a determinado precio
for key, value in datos.items():
  if (value)>100000:
    print(key)
# Out:
# Passat
# Cruze

# %%
# Ejemplo:
datos_3 = {
    'Crossfox': {'valor': 72000, 'año': 2005},
    'DS5': {'valor': 125000, 'año': 2015},
    'Fusca': {'valor': 150000, 'año': 1976},
    'Jetta': {'valor': 88000, 'año': 2010},
    'Passat': {'valor': 106000, 'año': 1998}
}

# Consigna
'''
Selecciona la alternativa que muestre el código que imprima sólo los nombres
de los vehículos que tengan el año de fabricación mayor o igual a 2000.
'''

# %%
# Observa que datos_3.items() devuelve un iterador de tuplas, donde cada tupla
# tiene como primer ítem la llave del diccionario y como segundo ítem su respectivo valor:

for item in datos_3.items():
  print(item)
# Out:
# ('Crossfox', {'valor': 72000, 'año': 2005})
# ('DS5', {'valor': 125000, 'año': 2015})
# ('Fusca', {'valor': 150000, 'año': 1976})
# ('Jetta', {'valor': 88000, 'año': 2010})
# ('Passat', {'valor': 106000, 'año': 1998})

# %%
# Para acceder a la clave del diccionario, basta utilizar ítem[0],
# y para acceder al valor, basta usar ítem[1].
# ítem [0] = marca de autos
# ítem [1] = elementos dentro de las {}
# [año] = me da el valor asignado a esa key

for item in datos_3.items():
  # Para acceder el año dentro del diccionario, usamos item[1] ['año']
  if(item[1]['año']>= 2000):
    print(item[0])
# Out:
# Crossfox
# DS5
# Jetta

# %% [markdown]
# # <font color=green> 4. FUNCIONES Y PAQUETES
# ---
#
# Funciones son unidades de código reutilizables que realizan una tarea específica, pueden recibir alguna entrada y también pueden devolver algún resultado.

# %% [markdown]
# # 4.1 Built-in function
#
# El lenguaje Python tiene varias funciones integradas que siempre están accesibles. Algunas ya las usamos en nuestro entrenamiento:
# type(), print(), zip(), len(), set() etc.
#
# https://docs.python.org/3.6/library/functions.html

# %%
datos = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
datos
# Out:
# {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}

# %%
# vamos a realizar operaciones sin utilizar "Built-in function"
# Extraemos los valores = values del diccionario y los colocamos en un lista
valores = []
for valor in datos.values():
  valores.append(valor)
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
# sumamos los valores que tenemos dentro de la lista
suma = 0
for valor in datos.values():
  suma += valor
suma
# Out:
# 267072.74

# %%
# Ahora lo realizamos utilizando "Built-in function" (Funciones predeterminadas de Python)
list(datos.values())
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
# Ahora sumamos utilizando "Built-in function"
sum(datos.values())
# Out:
# 267072.74

# %%
# Utilizamos el método -help()- para obtener toda la documentación del método -print()-
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
# De esta forma tenemos la misma información que el método -help()-
print?

# %%
'''
Recordamos algunas de las "Built-in function" utilizadas:

-La función zip() es muy útil cuando necesitamos iterar en más de una secuencia
 al mismo tiempo. También se usa ampliamente junto con la función dict()
 para crear diccionarios.

-Usamos la función dict() para crear diccionarios.

-La función type() esta built-in function para identificar con qué tipos de datos estamos trabajando.
'''

# %% [markdown]
# # 4.2 Definiendo funciones sin y con parámetros

# %% [markdown]
# ### Funciones sin parámetros
#
# #### Formato estándar
#
# ```
# def <nombre>():
#     <instrucciones>
# ```

# %%
# Creamos una función para sacar promedio
def media():
  valor  = (1+2+3)/3
  print(valor)
# no imprime nada aún por lo que no hemos llamado a la función para poder ver el resultado

# %%
# llamamos a la función
media()
# Out:
# 2.0

# %% [markdown]
# ### Funciones con parámetros
#
# #### Formato estándar
#
# ```
# def <nombre>(<param_1>, <param_2>, ..., <param_n>):
#     <instrucciones>
# ```

# %%
# En este caso le vamos a pasar parámetros a la función
def media(number_1, number_2, number_3):
  valor  = (number_1 + number_2 + number_3)/3
  print(valor)

# %%
# Parámetros que pasamos
media(1,2,3)
# Out:
# 2.0

# %%
# Colocamos otros parámetros mas grandes
media(22,55,84)
# Out:
# 53.666666666666664

# %%
# Vamos a realizar una función la cual me reciba 'n-numeros' a través de una lista
# con el len() para tener en cuenta la longitud de la lista y calcular el promedio

def media(lista):
  valor  = sum(lista)/len(lista)
  print(valor)
# Ejecutamos para darle existencia nuestro código

# %%
# Le damos los elementos de la lista para realizar la operación
# Esta Función NO devuelve valores
media([1,2,3,4,5,6,7,8])
# Out:
# 4.5

# %%
# A la variable resultado le asignamos media()
resultado = media([1,2,3,4,5,6,7,8])
# Out:
# 4.5

# %%
# Al imprimir vemos que no retorna ningún resultado por lo que lo que hace media()
# es imprimir el resultado de la funcion
resultado

# %%
# Vemos que 'resultado' no tiene ningún tipo
type(resultado)
# Out:
# NoneType

# %%
# Ejemplo:
# Calcular el kilometraje promedio que recorre un vehículo por año.
# No hay una función lista para calcular esta estadística en Python,
# por lo que necesitamos escribir una función que obtenga este valor.

# km_media = km_total / (año_actual - año_fabricación)

datos = {
    'Crossfox': {'km': 35000, 'año': 2005},
    'DS5': {'km': 17000, 'año': 2015},
    'Fusca': {'km': 130000, 'año': 1979},
    'Jetta': {'km': 56000, 'año': 2011},
    'Passat': {'km': 62000, 'año': 1999}
}

# %%
def km_media(dataset, año_actual):
    for item in datos.items():
        result = item[1]['km'] / (año_actual - item[1]['año'])
        print(result)

'''
-En algunas situaciones, esto puede hasta parecer correcto,
incluso puede devolver valores correctos, dependiendo de cómo se esté
escribiendo su código, pero no es posible reutilizar este código.
-Observa que en la construcción de la función definimos dos argumentos
(dataset y año_actual). Las instrucciones de la función deben usar estos
argumentos y no el nombre de una variable que se ha definido en otra
parte de nuestro código (datos).
'''

# %%
# Forma Correcta de como realizarlo
def km_media(dataset, año_actual):
    for item in dataset.items():
      result =  item[1]['km'] / (año_actual - item[1]['año'])
      print(result)

# %%
km_media(datos, 2019)
# Out:
# 2500.0
# 4250.0
# 3250.0
# 7000.0
# 3100.0

# %% [markdown]
# # 4.3 Definiendo funciones que devuelven valores

# %% [markdown]
# ### Funciones que devuelven un valor
#
# #### Formato estándar
#
# ```
# def <nombre>(<param_1>, <param_2>, ..., <param_n>):
#     <instrucciones>
#     return <resultado>
# ```

# %%
# En este caso vamos a retornar un valor, por lo que me está devolviendo valor
def media(lista):
  valor  = sum(lista)/len(lista)
  return(valor)

# %%
# A diferencia del ejemplo anterior donde nos lo que hace es imprimir un valor, en este caso
# nos retorna el valor
media([1,2,3,4,5,6,7,8])
# Out:
# 4.5

# %%
resultado = media([1,2,3,4,5,6,7,8])

# %%
# en este caso si nos devuelve valor
resultado
# Out:
# 4.5

# %% [markdown]
# ### Funciones que devuelven más de un valor
#
# #### Formato estándar
#
# ```
# def <nombre>(<param_1>, <param_2>, ..., <param_n>):
#     <instrucciones>
#     return (<resultado_1>, <resultado_2>, ..., <resultado_n>)
# ```

# %%
# En este caso nos va a devolver el promedio y el tamaño de la lista
def media(lista):
  valor  = sum(lista)/len(lista)
  return(valor, len(lista))

# %%
# Vemos que nos devuelve una tupla donde en el primer número es el promedio y
# el segundo el tamaño
media([1,2,3,4,5,6,7,8])
# Out:
# (4.5, 8)

# %%
# creamos dos variables separadas para desempacar
resultado, n = media([1,2,3,4,5,6,7,8])

# %%
# En la variable "resultado" vemos el valor del promedio
resultado
# Out:
# 4.5

# %%
# En la variable "n" vemos del tamaño de la lista
n
# Out:
# 8

# %%
# Ejemplo:

datos = {
    'Crossfox': {'km': 35000, 'año': 2005},
    'DS5': {'km': 17000, 'año': 2015},
    'Fusca': {'km': 130000, 'año': 1979},
    'Jetta': {'km': 56000, 'año': 2011},
    'Passat': {'km': 62000, 'año': 1999}
}
'''
La siguiente estructura es la definición de una función que calcula el
kilometraje promedio anual de cada vehículo y devuelve un diccionario con
los nombres de los vehículos como llaves y el kilometraje promedio como valores:
'''

# %%
def km_media(dataset, año_actual):
    result = {}
    for item in dataset.items():
        media = item[1]['km'] / (año_actual - item[1]['año'])
        result.update({item[0]:media})
    return(result)

'''
IMPORTANTE
El método append() es un método de listas de Python. POR ESO NO LO UTILIZAMOS
Para actualizar diccionarios, usamos el método update().
'''

# %%
km_media(datos, 2019)
# Out:
# {'Crossfox': 2500.0,
#  'DS5': 4250.0,
#  'Fusca': 3250.0,
#  'Jetta': 7000.0,
#  'Passat': 3100.0}

# %%
# Otro Ejemplo:
datos = {
    'Crossfox': {'km': 35000, 'año': 2005},
    'DS5': {'km': 17000, 'año': 2015},
    'Fusca': {'km': 130000, 'año': 1979},
    'Jetta': {'km': 56000, 'año': 2011},
    'Passat': {'km': 62000, 'año': 1999}
}

'''
La siguiente estructura es la definición de una función que calcula el
kilometraje promedio anual de cada vehículo, actualiza el diccionario
de entrada y devuelve este diccionario:
'''

# %%
def km_media(dataset, año_actual):
    result = {}
    for item in dataset.items():
        # media = kilometro promedio anual
        media = item[1]['km'] / (año_actual - item[1]['año'])
        # item[1] guardamos información de los vehículos
        item[1].update({'km_medio':media})
        #se guarda en el diccionario result, el resultado de las operaciones
        result.update({item[0]:item[1]})
    return result

# %%
km_media(datos, 2019)
# Out:
# {'Crossfox': {'km': 35000, 'año': 2005, 'km_medio': 2500.0},
#  'DS5': {'km': 17000, 'año': 2015, 'km_medio': 4250.0},
#  'Fusca': {'km': 130000, 'año': 1979, 'km_medio': 3250.0},
#  'Jetta': {'km': 56000, 'año': 2011, 'km_medio': 7000.0},
#  'Passat': {'km': 62000, 'año': 1999, 'km_medio': 3100.0}}

# %% [markdown]
# # <font color=green> 5. PANDAS BÁSICO
# ---
#
# **versión: 1.1.0**
#
# Pandas es una herramienta de manipulación de datos de alto nivel, construida sobre la base del paquete Numpy. El paquete pandas tiene estructuras de datos muy interesantes para la manipulación de datos y, por esto, es ampliamente utilizado por los científicos de datos.
#
#
# ## Estructuras de Datos
#
# ### Series
#
# Series son arrays unidimensionales etiquetados capaces de almacenar cualquier tipo de dato. Las etiquetas de las líneas se denominan **index**. La forma básica de crear una Series es la siguiente:
#
#
# ```
#     s = pd.Series(datos, index = index)
# ```
#
# El argumento *datos* puede ser un diccionario, una lista, un array Numpy o una constante.
#
# ### DataFrames
#
# DataFrame es una estructura de datos tabular bidimensional con etiquetas de fila y columna. Como la Series, los DataFrames son capaces de almacenar cualquier tipo de datos.
#
#
# ```
#     df = pd.DataFrame(datos, index = index, columns = columns)
# ```
#
# El argumento *datos* puede ser un diccionario, una lista, un array Numpy, una Series y otro DataFrame.
#
# **Documentación:** https://pandas.pydata.org/pandas-docs/version/1.1.0/

# %% [markdown]
# # 5.1 Estructuras de datos

# %%
import pandas as pd

# %% [markdown]
# ### Creando una Series a partir de una lista

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
pd.Series(carros)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# ### Creando un DataFrame a partir de una lista de diccionarios

# %%
datos = [
    {'Nombre': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Año': 2003, 'Kilometraje': 44410.0, 'Cero_km': False, 'Valor': 88078.64},
    {'Nombre': 'Passat', 'Motor': 'Motor Diesel', 'Año': 1991, 'Kilometraje': 5712.0, 'Cero_km': False, 'Valor': 106161.94},
    {'Nombre': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Año': 1990, 'Kilometraje': 37123.0, 'Cero_km': False, 'Valor': 72832.16}
]

# %%
# Transformamos la lista datos en un DataFrame
dataset = pd.DataFrame(datos)

# %%
dataset
# Out:
#           Nombre            Motor   Año  Kilometraje  Cero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003      44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991       5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990      37123.0    False   72832.16

# %%
# De esta forma se puede modificar el orden de las columnas
dataset[['Nombre', 'Año', 'Motor', 'Kilometraje', 'Cero_km', 'Valor']]
# Out:
#           Nombre   Año            Motor  Kilometraje  Cero_km      Valor
# 0  Jetta Variant  2003  Motor 4.0 Turbo      44410.0    False   88078.64
# 1         Passat  1991     Motor Diesel       5712.0    False  106161.94
# 2       Crossfox  1990  Motor Diesel V8      37123.0    False   72832.16

# %% [markdown]
# ### Creando un DataFrame a partir de un diccionario

# %%
datos = {
    'Nombre': ['Jetta Variant', 'Passat', 'Crossfox'],
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Año': [2003, 1991, 1990],
    'Kilometraje': [44410.0, 5712.0, 37123.0],
    'Cero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
# Transformamos un diccionario datos en un DataFrame
dataset = pd.DataFrame(datos)

# %%
dataset
# Out:
#           Nombre            Motor   Año  Kilometraje  Cero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003      44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991       5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990      37123.0    False   72832.16

# %% [markdown]
# ### Creando un DataFrame a partir de un archivo externo

# %%
# Traemos un archivo externo para crear un DataFrame
# vamos a utilizar el método -read_csv- por lo que el archivo que vamos a traer es un csv
dataset = pd.read_csv('db.csv', sep = ';')

# %%
dataset
# Out:
#                     Nombre                  Motor   Año  Kilometraje  Cero_km  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003      44410.0    False
# 1                   Passat           Motor Diesel  1991       5712.0    False
# 2                 Crossfox        Motor Diesel V8  1990      37123.0    False
# 3                      DS5        Motor 2.4 Turbo  2019          NaN     True
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006      25757.0    False
# ..                     ...                    ...   ...          ...      ...
# 253           Phantom 2013               Motor V8  2014      27505.0    False
# 254  Cadillac Ciel concept               Motor V8  1991      29981.0    False
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# 256       Aston Martin DB5           Motor Diesel  1996       7685.0    False
# 257                  Macan        Motor Diesel V6  1992      50188.0    False
#
# ...

# %%
# también lo que podemos hacer es cambiar las columnas, vamos a cambiar la columna
# para que el índice sea el nombre y no el determinado por panda, lo realizamos
# colocando un nuevo parámetro -index_col-.
dataset = pd.read_csv('db.csv', sep = ';', index_col=0)

# %%
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Ejemplo: tomamos un ejemplo anterior para poder realizar un DataFrame
datos = {
    'Crossfox': {'km': 35000, 'año': 2005},
    'DS5': {'km': 17000, 'año': 2015},
    'Fusca': {'km': 130000, 'año': 1979},
    'Jetta': {'km': 56000, 'año': 2011},
    'Passat': {'km': 62000, 'año': 1999}
}

# %%
def km_media(dataset, año_actual):
    result = {}
    for item in dataset.items():
        media = item[1]['km'] / (año_actual - item[1]['año'])
        item[1].update({ 'km_media': media })
        result.update({ item[0]: item[1] })

    return result

# %%
km_media(datos, 2019)
# Out:
# {'Crossfox': {'km': 35000, 'año': 2005, 'km_media': 2500.0},
#  'DS5': {'km': 17000, 'año': 2015, 'km_media': 4250.0},
#  'Fusca': {'km': 130000, 'año': 1979, 'km_media': 3250.0},
#  'Jetta': {'km': 56000, 'año': 2011, 'km_media': 7000.0},
#  'Passat': {'km': 62000, 'año': 1999, 'km_media': 3100.0}}

# %%
# Obtener un DataFrame donde las columnas sean el primer índice el nombre de los carros, Km, Año, Km_media
'''
Para resolver este problema, será necesario recordar un recurso que aprendimos
en el curso anterior, cuando hablamos de arrays Numpy.
Este recurso también se puede aplicar a DataFrames de pandas:

"ndarray.T: Devuelve la matriz transpuesta, es decir, convierte filas en columnas y viceversa."
'''
import pandas as pd
carros = pd.DataFrame(km_media(datos, 2019)).T

# La propiedad T es una forma de acceder al método transpose() del DataFrame.

# %%
carros
# Out:
#                 km     año  km_media
# Crossfox   35000.0  2005.0    2500.0
# DS5        17000.0  2015.0    4250.0
# Fusca     130000.0  1979.0    3250.0
# Jetta      56000.0  2011.0    7000.0
# Passat     62000.0  1999.0    3100.0

# %%
# Podemos observar que si no utilizamos el recurso para hacer que la matriz sea
# transpuestas (.T) nos queda cada fila del diccionario como una columna del DataFrame
import pandas as pd
carros = pd.DataFrame(km_media(datos, 2019))

# %%
carros
# Out:
#           Crossfox      DS5     Fusca    Jetta   Passat
# km         35000.0  17000.0  130000.0  56000.0  62000.0
# año         2005.0   2015.0    1979.0   2011.0   1999.0
# km_media    2500.0   4250.0    3250.0   7000.0   3100.0

# %% [markdown]
# # 5.2 Selecciones con DataFrames

# %%
# Queremos ver las primeras filas del dataset
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %% [markdown]
# ### Seleccionando columnas

# %%
# Comenzamos a buscar datos por columnas y observamos que el formato que arroja es 'Serie'
dataset['Valor']
# Out:
# Nombre
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# Classe GLK                68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Valor, Length: 258, dtype: float64
# Nombre
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# Classe GLK                68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
# Corroboramos el tipo
type(dataset['Valor'])
# Out:
# pandas.core.series.Series

# %%
# Para que el formato sea un 'DataFrame' y no 'Serie' lo realizamos de la
# siguiente forma agregando [[]]
dataset[['Valor']]
# Out:
#                            Valor
# Nombre
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 1 columns]

# %%
# Vemos que ahora el tipo es un DataFrame
type(dataset[['Valor']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Ejemplo:
# Elige la alternativa que contenga el código que selecciona solamente las
# informaciones de Nombre, Año, Kilometraje y Valor de los vehículos Passat y Crossfox.

import pandas as pd

datos = {
   'Nombre': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'],
   'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Año': [2019, 2003, 1991, 2019, 1990],
    'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Cero_km': [True, False, False, True, False],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

# %%
dataset = pd.DataFrame(datos)

# %%
# Observamos que, el orden en el que definimos las selecciones es indiferente:
# dataset[1:3][['Nombre', 'Año', 'Kilometraje, 'Valor']]
# Cuando necesitamos seleccionar más de una columna de un DataFrame, debemos pasar corchetes dobles

dataset[['Nombre', 'Año', 'Kilometraje', 'Valor']][1:3]
# Out:
#      Nombre   Año  Kilometraje     Valor
# 1    Passat  2003       5712.0  106000.0
# 2  Crossfox  1991      37123.0   72000.0

# %% [markdown]
# ### Seleccionando lineas - [ i : j ]
#
# <font color=red>**Observación:**</font> La indexación tiene origen en cero y en las particiones(*slices*) la línea con índice i es **incluída** y la línea con índice j **no es incluída** en el resultado.

# %%
# Vamos a seleccionar para poder ver solo las primeras 3 filas
dataset[0:3]
# Out:
#                          Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant  Motor 4.0 Turbo  2003      44410.0    False
# Passat            Motor Diesel  1991       5712.0    False
# Crossfox       Motor Diesel V8  1990      37123.0    False
#
#                                                       Accesorios      Valor
# Nombre
# Jetta Variant  ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat         ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox       ['Piloto automático', 'Control de estabilidad'...   72832.16

# %% [markdown]
# ### Utilizando .loc para selecciones
#
# <font color=red>**Observación:**</font> Selecciona un grupo de líneas y columnas según las etiquetas o una matriz booleana.

# %%
# Utilizamos el método '.loc' me trae como resultado, filas y columnas según su etiqueta
dataset.loc['Passat']
# Out:
# Motor                                               Motor Diesel
# Año                                                         1991
# Kilometraje                                               5712.0
# Cero_km                                                    False
# Accesorios     ['Central multimedia', 'Techo panorámico', 'Fr...
# Valor                                                  106161.94
# Name: Passat, dtype: object

# %%
# Buscamos 2 vehículos, tener en cuanta que cuando buscamos mas de un índex (vehículo)
# tenemos que utilizar [[]] si no, nos da error
dataset.loc[['Passat', 'DS5']]
# Out:
#                   Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Passat     Motor Diesel  1991       5712.0    False
# DS5     Motor 2.4 Turbo  2019          NaN     True
#
#                                                Accesorios      Valor
# Nombre
# Passat  ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# DS5     ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07

# %%
# En este caso vamos a buscar de forma más detallada [[filas],[columnas]]
dataset.loc[['Passat', 'DS5'],['Motor', 'Valor']]
# Out:
#                   Motor      Valor
# Nombre
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
# En el caso de querer ver todas las filas pero solo dos columnas
dataset.loc[:,['Motor', 'Valor']]
# Out:
#                                        Motor      Valor
# Nombre
# Jetta Variant                Motor 4.0 Turbo   88078.64
# Passat                          Motor Diesel  106161.94
# Crossfox                     Motor Diesel V8   72832.16
# DS5                          Motor 2.4 Turbo  124549.07
# Aston Martin DB4             Motor 2.4 Turbo   92612.10
# ...                                      ...        ...
# Phantom 2013                        Motor V8   51759.58
# Cadillac Ciel concept               Motor V8   51667.06
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03
# Aston Martin DB5                Motor Diesel  122110.90
# Macan                        Motor Diesel V6   90381.47
#
# [258 rows x 2 columns]

# %% [markdown]
# ### Utilizando .iloc para selecciones
#
# <font color=red>**Observación:**</font> Selecciona con base en los índices, es decir, utiliza la posición de las informaciones.

# %%
# Utilizamos el método -head()- para ver las primeras filas de nuestro dataset
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %%
# Con el médoto -.iloc- buscamos por posición
dataset.iloc[[1]]
# Out:
#                Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Passat  Motor Diesel  1991       5712.0    False
#
#                                                Accesorios      Valor
# Nombre
# Passat  ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94

# %%
# Cuando busco un intervalo de filas, para buscar un intervalo no debería
# utilizar [[]], se realiza con un solo []
dataset.iloc[1:4]
# Out:
#                     Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Passat       Motor Diesel  1991       5712.0    False
# Crossfox  Motor Diesel V8  1990      37123.0    False
# DS5       Motor 2.4 Turbo  2019          NaN     True
#
#                                                  Accesorios      Valor
# Nombre
# Passat    ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox  ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5       ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07

# %%
# Aquí se busca por las columnas que quiero ver en un intervalo de filas
# de esta forma empezamos a ordenar según lo que necesitamos
dataset.iloc[1:4, [0, 5, 2]]
# Out:
#                     Motor      Valor  Kilometraje
# Nombre
# Passat       Motor Diesel  106161.94       5712.0
# Crossfox  Motor Diesel V8   72832.16      37123.0
# DS5       Motor 2.4 Turbo  124549.07          NaN

# %%
# Ahora lo realizamos filtrando algunas filas no un intervalo de filas
dataset.iloc[[1, 42, 22], [0, 5, 2]]
# Out:
#                                Motor      Valor  Kilometraje
# Nombre
# Passat                  Motor Diesel  106161.94       5712.0
# Optima                 Motor 1.8 16v   86641.34          NaN
# Lamborghini Obvious  Motor Diesel V6  133529.84      98079.0

# %%
# Ahora para ver todas las filas
dataset.iloc[:, [0, 5, 2]]
# Out:
#                                        Motor      Valor  Kilometraje
# Nombre
# Jetta Variant                Motor 4.0 Turbo   88078.64      44410.0
# Passat                          Motor Diesel  106161.94       5712.0
# Crossfox                     Motor Diesel V8   72832.16      37123.0
# DS5                          Motor 2.4 Turbo  124549.07          NaN
# Aston Martin DB4             Motor 2.4 Turbo   92612.10      25757.0
# ...                                      ...        ...          ...
# Phantom 2013                        Motor V8   51759.58      27505.0
# Cadillac Ciel concept               Motor V8   51667.06      29981.0
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03      52637.0
# Aston Martin DB5                Motor Diesel  122110.90       7685.0
# Macan                        Motor Diesel V6   90381.47      50188.0
#
# [258 rows x 3 columns]

# %%
# Ejemplo:

import pandas as pd

datos = {
   'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
   'Año': [2019, 2003, 1991, 2019, 1990],
   'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
   'Cero_km': [True, False, False, True, False],
   'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

dataset = pd.DataFrame(datos, index = ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'])

# Observa que usamos los nombres de los vehículos como índice del DataFrame.

# %%
# En este caso utilizamos el método -.loc- para buscar por el índice
dataset.loc[['Passat', 'DS5'], ['Motor', 'Valor']]

# Usando .loc, podemos hacer las selecciones usando los rótulos de las filas y las columnas de un DataFrame.
# Out:
#                Motor     Valor
# Passat  Motor Diesel  106000.0
# DS5        Motor 2.0   89000.0

# %%
# En este caso utilizamos el método -.iloc- para buscar por posición
dataset.iloc[[1,4],[0,-1]]

# Usando .iloc, las selecciones se hacen por la posición de las filas y las columnas,
# es decir, usando los índices numéricos del DataFrame.
# Out:
#                Motor     Valor
# Passat  Motor Diesel  106000.0
# Fusca      Motor 1.6   32000.0

# %% [markdown]
# # 5.3 Consultas en DataFrames

# %%
# Traemos nuevamente el archivo para saber con qué archivo estamos trabajando
dataset = pd.read_csv('db.csv', sep = ';', index_col=0)

# %%
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %%
# Cuando las etiquetas "Motor", "Año", "Kilometraje". etc no tienen espacio
# como vemos arriba, podemos hacer la selección de otra forma

dataset.Motor
# Out:
# Nombre
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
# En este caso buscamos dentro de 'Motor', cuales son 'Motores Diesel' obteniendo
# un resultado buleano
dataset.Motor == 'Motor Diesel'
# Out:
# Nombre
# Jetta Variant            False
# Passat                    True
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5          True
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
type(dataset.Motor == 'Motor Diesel')
# Out:
# pandas.core.series.Series

# %%
# Ahora lo que vamos a realizar pero que nos devuelva las filas que cumplen con el criterio
# vamos a colocar un filtro más, para buscar otro criterio mas
dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Cero_km == True)]

# vemos que obtenemos como resultado aquellos vehículos cero km y que tengan el motor Diesel
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Sorento              Motor Diesel  2019          NaN     True
# Cielo Hatch          Motor Diesel  2019          NaN     True
# Camry                Motor Diesel  2019          NaN     True
# Aston Martin Virage  Motor Diesel  2019          NaN     True
# Série 7 Sedã         Motor Diesel  2019          NaN     True
#
#                                                             Accesorios  \
# Nombre
# Sorento              ['Sensor de lluvia', 'Cámara de estacionamient...
# Cielo Hatch          ['Panel digital', 'Central multimedia', 'Cámar...
# Camry                ['Cerraduras electricas', 'Llantas de aleación...
# Aston Martin Virage  ['Cerraduras electricas', 'Control de tracción...
# Série 7 Sedã         ['Ventanas eléctricas', 'Cerraduras electricas...
#
#                          Valor
# Nombre
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %% [markdown]
# ### Utilizando el método query

# %%
# En este caso vamos a buscar utilizando el método -quey- que se realiza mediante cadena de texto
dataset.query('Motor == "Motor Diesel" and Cero_km == True')
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Sorento              Motor Diesel  2019          NaN     True
# Cielo Hatch          Motor Diesel  2019          NaN     True
# Camry                Motor Diesel  2019          NaN     True
# Aston Martin Virage  Motor Diesel  2019          NaN     True
# Série 7 Sedã         Motor Diesel  2019          NaN     True
#
#                                                             Accesorios  \
# Nombre
# Sorento              ['Sensor de lluvia', 'Cámara de estacionamient...
# Cielo Hatch          ['Panel digital', 'Central multimedia', 'Cámar...
# Camry                ['Cerraduras electricas', 'Llantas de aleación...
# Aston Martin Virage  ['Cerraduras electricas', 'Control de tracción...
# Série 7 Sedã         ['Ventanas eléctricas', 'Cerraduras electricas...
#
#                          Valor
# Nombre
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %%
# Ejemplo
import pandas as pd

datos = {
  'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor Diesel', 'Motor 1.6'],
    'Año': [2019, 2003, 1991, 2019, 1990],
    'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Cero_km': [True, False, False, True, False],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

dataset = pd.DataFrame(datos, index = ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'])

# Vamos a ver 3 formas diferentes de obtener el mismo resultado

# %%
'''
 El método query() acepta las 2 formas de utilización de operadores lógicos.
 En el caso del operador lógico O, tenemos el or y el carácter |.
 Para el operador lógico Y, tenemos el and y el carácter &.
'''
dataset.query('Motor == "Motor Diesel" | Cero_km == True')
# Out:
#                   Motor   Año  Kilometraje  Cero_km     Valor
# Jetta   Motor 4.0 Turbo  2019          0.0     True   88000.0
# Passat     Motor Diesel  2003       5712.0    False  106000.0
# DS5        Motor Diesel  2019          0.0     True   89000.0

# %%
'''
En la construcción de la matriz booleana que utilizamos para realizar la consulta,
fue utilizado el operador lógico O, que en el caso del código anterior
está representado por el carácter |.

A diferencia del método query(), no es posible usar el operador lógico O
con la palabra or, en el caso de la construcción anterior.
En este caso, para crear una matriz booleana, el operador correcto es |

"dataset[(dataset.Motor == 'Motor Diesel') or (dataset.Cero_km == True)]"
'''

dataset[(dataset.Motor == 'Motor Diesel') | (dataset.Cero_km == True)]
# Out:
#                   Motor   Año  Kilometraje  Cero_km     Valor
# Jetta   Motor 4.0 Turbo  2019          0.0     True   88000.0
# Passat     Motor Diesel  2003       5712.0    False  106000.0
# DS5        Motor Diesel  2019          0.0     True   89000.0

# %%
'''
 El método query() acepta las 2 formas de utilización de operadores lógicos.
 En el caso del operador lógico O, tenemos el or y el carácter |.
 Para el operador lógico Y, tenemos el and y el carácter &.
'''

dataset.query('Motor == "Motor Diesel" or Cero_km == True')
# Out:
#                   Motor   Año  Kilometraje  Cero_km     Valor
# Jetta   Motor 4.0 Turbo  2019          0.0     True   88000.0
# Passat     Motor Diesel  2003       5712.0    False  106000.0
# DS5        Motor Diesel  2019          0.0     True   89000.0

# %% [markdown]
# # 5.4 Iterando con DataFrames

# %%
# Recordamos que tenemos que importar la biblioteca pandas
import pandas as pd

# %%
# Recordamos que importamos el archivo externo csv para poder trabajar con el DataFrame
dataset = pd.read_csv('db.csv', sep = ';', index_col=0)

# %%
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios      Valor
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...   88078.64
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...  106161.94
# Crossfox          ['Piloto automático', 'Control de estabilidad'...   72832.16
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...  124549.07
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...   92612.10

# %%
# iteramos el DataFrame, de esta forma vamos a poder ver las columnas
for item in dataset:
  print(item)
# de esta forma vamos a poder ver las columnas o las etiquetas del DataFrame
# Out:
# Motor
# Año
# Kilometraje
# Cero_km
# Accesorios
# Valor

# %%
# otra de la forma es utilizamos el método -iterrows()- nos devuelve tuplas 2 valores
# el primero es el índice donde están los nombres de los vehículos y la 2da son los
# elementos de la fila

list(dataset.iterrows())
# Out:
# [('Jetta Variant',
#   Motor                                            Motor 4.0 Turbo
#   Año                                                         2003
#   Kilometraje                                              44410.0
#   Cero_km                                                    False
#   Accesorios     ['Llantas de aleación', 'Cerraduras electricas...
#   Valor                                                   88078.64
#   Name: Jetta Variant, dtype: object),
#  ('Passat',
#   Motor                                               Motor Diesel
#   Año                                                         1991
#   Kilometraje                                               5712.0
#   Cero_km                                                    False
#   Accesorios     ['Central multimedia', 'Techo panorámico', 'Fr...
#   Valor                                                  106161.94
#   Name: Passat, dtype: object),
#  ('Crossfox',
# ...

# %%
# Como este método -iterrows()- nos devuelve tuplas, lo que vamos hacer es desempacar la tupla
# y separarla en dos variables
for index, row in dataset.iterrows():
  # estamos dentro de cada fila
  if(2020 - row.Año != 0):
    # Aplicamos el método -loc- para ubicarnos dentro [fila,columna], eso quiere decir
    # que vamos a guardar en la misma fila pero en la columna nueva 'km_media'
    dataset.loc[index, 'Km_media'] = row.Kilometraje / (2020 - row.Año)
  # Cuando el año de fabricación sea = al Año actual
  else:
    dataset.loc[index, 'Km_media'] = 0
dataset
# Observamos que tenemos el DataFrame original, pero se le ha sumado la columna Km-media
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Pasamos en limpio la iteración del DataFrame
for index, row in dataset.iterrows():
  if(2020 - row.Año != 0):
    dataset.loc[index, 'Km_media'] = row.Kilometraje / (2020 - row.Año)
  else:
    dataset.loc[index, 'Km_media'] = 0
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Otras formas de Iterar con un DataFrame

'''
- itertuples() -
Este método itera a través de las líneas del DataFrame,
usando una tupla nombrada con el contenido de cada línea del DataFrame
'''
'''
- iterrows() -
Este fue el método que vimos en nuestra clase
'''
'''
- items() -
Itera a través de las columnas del DataFrame, usando una tupla,
donde el primer elemento es el nombre de la columna y el segundo es una Series,
con todo el contenido de la columna
'''

# %% [markdown]
# # 5.5 Tratamiento de datos

# %%
'''
El tratamiento de datos lo vamos a realizar para mejorar la calidad del dato
'''
dataset.head()
# Out:
#                             Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant     Motor 4.0 Turbo  2003      44410.0    False
# Passat               Motor Diesel  1991       5712.0    False
# Crossfox          Motor Diesel V8  1990      37123.0    False
# DS5               Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006      25757.0    False
#
#                                                          Accesorios  \
# Nombre
# Jetta Variant     ['Llantas de aleación', 'Cerraduras electricas...
# Passat            ['Central multimedia', 'Techo panorámico', 'Fr...
# Crossfox          ['Piloto automático', 'Control de estabilidad'...
# DS5               ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# Aston Martin DB4  ['Llantas de aleación', '4 X 4', 'Central mult...
#
#                       Valor     Km_media
# Nombre
# Jetta Variant      88078.64  2612.352941
# Passat            106161.94   196.965517
# ...

# %%
# Vemos la información del DataFrame
dataset.info()

# Vemos que dentro que en el DataFrame en la columna 'Kilometraje' tenemos dos formas
# de solucionarlo, podemos eliminar las filas con valores nulos o las corregimos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Motor        258 non-null    object
#  1   Año          258 non-null    int64
#  2   Kilometraje  197 non-null    float64
#  3   Cero_km      258 non-null    bool
#  4   Accesorios   258 non-null    object
#  5   Valor        258 non-null    float64
#  6   Km_media     197 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
# Aplicamos el método -isna()- tenemos como resultado una seria con valores bool
dataset.Kilometraje.isna()
# Out:
# Nombre
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Kilometraje, Length: 258, dtype: bool

# %%
# buscamos dentro del dataset utilizando como parámetro una serie bool, de esta
# forma vamos a obtener todas las filas de la columna 'Kilometraje' con valor nulo

dataset[dataset.Kilometraje.isna()]

# Podemos ver que todos los vehículos que aparecen con el valor NaN es porque son
# cero kilometro
# Out:
#                                 Motor   Año  Kilometraje  Cero_km  \
# Nombre
# DS5                   Motor 2.4 Turbo  2019          NaN     True
# A5                    Motor 4.0 Turbo  2019          NaN     True
# J5                           Motor V6  2019          NaN     True
# A3                       Motor 1.0 8v  2019          NaN     True
# Série 1 M                    Motor V8  2019          NaN     True
# ...                               ...   ...          ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019          NaN     True
# Benni Mini                   Motor V8  2019          NaN     True
# Uno                   Motor Diesel V6  2019          NaN     True
# Santa Fe                Motor 3.0 32v  2019          NaN     True
# XC60                  Motor 4.0 Turbo  2019          NaN     True
#
#                                                              Accesorios  \
# Nombre
# DS5                   ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# ...

# %%
# Utilizamos el método -fillna()- para sustituir los valores de NaN por 0, tener
# en cuanta que este método solo lo va a sustituir en la visualización no en el dataset

dataset.fillna(0)
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          0.0     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Vemos que al ejecutar nuevamente el dataset no ha modificado los valores NaN
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Para sustituir NaN por 0 en el DataFrame  y no solo en la visualización
# le agregamos otro parámetro 'inplace = True' dentro del método -fillna()-
dataset.fillna(0, inplace = True)

# %%
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          0.0     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Realizamos una -query- para ver si los valores de Cero_km aparecen con los datos cambiados de NaN a 0
dataset.query('Cero_km == True')
# Out:
#                                 Motor   Año  Kilometraje  Cero_km  \
# Nombre
# DS5                   Motor 2.4 Turbo  2019          0.0     True
# A5                    Motor 4.0 Turbo  2019          0.0     True
# J5                           Motor V6  2019          0.0     True
# A3                       Motor 1.0 8v  2019          0.0     True
# Série 1 M                    Motor V8  2019          0.0     True
# ...                               ...   ...          ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019          0.0     True
# Benni Mini                   Motor V8  2019          0.0     True
# Uno                   Motor Diesel V6  2019          0.0     True
# Santa Fe                Motor 3.0 32v  2019          0.0     True
# XC60                  Motor 4.0 Turbo  2019          0.0     True
#
#                                                              Accesorios  \
# Nombre
# DS5                   ['Cerraduras electricas', '4 X 4', 'Ventanas e...
# ...

# %%
# En caso de no poder corregir el problema de los valores nulos, otro método es
# eliminar los datos, Cargamos el DataFran nuevamente para volver al original

dataset = pd.read_csv('db.csv', sep = ';', index_col=0)

# %%
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# DS5                          Motor 2.4 Turbo  2019          NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Para eliminar los valores de NaN vamos a utilizar el método -dropna()-
# recordamos de utilizar el parámetro 'inplace' para eliminar el dato del DataFrame
dataset.dropna(subset = ['Kilometraje'], inplace = True )

# %%
# Vemos ahora que en el DataFrame quedan 197 de las 258 filas que tenía por lo que
# se han eliminado todas las filas con valores nulos
dataset
# Out:
#                                        Motor   Año  Kilometraje  Cero_km  \
# Nombre
# Jetta Variant                Motor 4.0 Turbo  2003      44410.0    False
# Passat                          Motor Diesel  1991       5712.0    False
# Crossfox                     Motor Diesel V8  1990      37123.0    False
# Aston Martin DB4             Motor 2.4 Turbo  2006      25757.0    False
# Palio Weekend                  Motor 1.8 16v  2012      10728.0    False
# ...                                      ...   ...          ...      ...
# Phantom 2013                        Motor V8  2014      27505.0    False
# Cadillac Ciel concept               Motor V8  1991      29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# Aston Martin DB5                Motor Diesel  1996       7685.0    False
# Macan                        Motor Diesel V6  1992      50188.0    False
#
#                                                               Accesorios  \
# ...

# %%
# Repaso de los últimos métodos vistos para el tratamiento de datos en un DataFrame

'''
El método isna() se utiliza para identificar valores missing en Series y en DataFrames.
'''

'''
El método dropna() elimina los valores identificados como missing.
'''

'''
El método fillna() usa un conjunto de métodos para completar los valores faltantes.
'''

# %%
# LO QUE HEMOS VISTO

'''
-Series y DataFrames, las estructuras de datos básicas de la biblioteca pandas.
-Los métodos para crear Series y DataFrames.
-A crear DataFrames a partir de datos externos.
-Cómo hacer selecciones y cortes en un DataFrame.
-Los métodos de selección .loc y .iloc.
-A realizar consultas en un DataFrame con el método .query() y con matrices booleanas.
-La forma básica de iterar sobre un DataFrame.
-Cómo tratar datos faltantes en un DataFrame (isna(), fillna() y dropna()).

'''
